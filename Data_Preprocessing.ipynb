# %% [markdown]
# Importing Important Python Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl

# %% [markdown]
# Loading Dataset

# %%
df = pd.read_csv('E-Commerce_Dataset.csv')
df
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 0          50001      1     4.0         Mobile Phone         3
# 1          50002      1     NaN                Phone         1
# 2          50003      1     NaN                Phone         1
# 3          50004      1     0.0                Phone         3
# 4          50005      1     0.0                Phone         1
# ...          ...    ...     ...                  ...       ...
# 5625       55626      0    10.0             Computer         1
# 5626       55627      0    13.0         Mobile Phone         1
# 5627       55628      0     1.0         Mobile Phone         1
# 5628       55629      0    23.0             Computer         3
# 5629       55630      0     8.0         Mobile Phone         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 0                 6.0           Debit Card  Female             3.0
# 1                 8.0                  UPI    Male             3.0
# ...

# %%
df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
df.dtypes
# Out:
# CustomerID                       int64
# Churn                            int64
# Tenure                         float64
# PreferredLoginDevice            object
# CityTier                         int64
# WarehouseToHome                float64
# PreferredPaymentMode            object
# Gender                          object
# HourSpendOnApp                 float64
# NumberOfDeviceRegistered         int64
# PreferedOrderCat                object
# SatisfactionScore                int64
# MaritalStatus                   object
# NumberOfAddress                  int64
# Complain                         int64
# OrderAmountHikeFromlastYear    float64
# CouponUsed                     float64
# OrderCount                     float64
# DaySinceLastOrder              float64
# CashbackAmount                   int64
# dtype: object

# %%
df.shape
# Out:
# (5630, 20)

# %%
df.isnull()
# Out:
#       CustomerID  Churn  Tenure  PreferredLoginDevice  CityTier  \
# 0          False  False   False                 False     False
# 1          False  False    True                 False     False
# 2          False  False    True                 False     False
# 3          False  False   False                 False     False
# 4          False  False   False                 False     False
# ...          ...    ...     ...                   ...       ...
# 5625       False  False   False                 False     False
# 5626       False  False   False                 False     False
# 5627       False  False   False                 False     False
# 5628       False  False   False                 False     False
# 5629       False  False   False                 False     False
#
#       WarehouseToHome  PreferredPaymentMode  Gender  HourSpendOnApp  \
# 0               False                 False   False           False
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
#data_prepocessing
df_transformed = df.copy()

# %% [markdown]
# ### Missing data handling

# %%
#mising data handling with median
df['Tenure']= df['Tenure'].fillna(df['Tenure'].median())

# %%
df['WarehouseToHome']= df['WarehouseToHome'].fillna(df['WarehouseToHome'].median())

# %%
df['HourSpendOnApp']= df['HourSpendOnApp'].fillna(df['HourSpendOnApp'].median())

# %%
df['OrderAmountHikeFromlastYear']= df['OrderAmountHikeFromlastYear'].fillna(df['OrderAmountHikeFromlastYear'].median())

# %%
df['CouponUsed']= df['CouponUsed'].fillna(df['CouponUsed'].median())

# %%
df['OrderCount']= df['OrderCount'].fillna(df['OrderCount'].median())

# %%
df['DaySinceLastOrder']= df['DaySinceLastOrder'].fillna(df['DaySinceLastOrder'].median())

# %%
df.isnull().sum()
# Out:
# CustomerID                     0
# Churn                          0
# Tenure                         0
# PreferredLoginDevice           0
# CityTier                       0
# WarehouseToHome                0
# PreferredPaymentMode           0
# Gender                         0
# HourSpendOnApp                 0
# NumberOfDeviceRegistered       0
# PreferedOrderCat               0
# SatisfactionScore              0
# MaritalStatus                  0
# NumberOfAddress                0
# Complain                       0
# OrderAmountHikeFromlastYear    0
# CouponUsed                     0
# OrderCount                     0
# DaySinceLastOrder              0
# CashbackAmount                 0
# dtype: int64

# %%
df.to_csv('cleaned.csv')

# %%
df.nunique()
# Out:
# CustomerID                     5630
# Churn                             2
# Tenure                           36
# PreferredLoginDevice              3
# CityTier                          3
# WarehouseToHome                  34
# PreferredPaymentMode              7
# Gender                            2
# HourSpendOnApp                    6
# NumberOfDeviceRegistered          6
# PreferedOrderCat                  6
# SatisfactionScore                 5
# MaritalStatus                     3
# NumberOfAddress                  15
# Complain                          2
# OrderAmountHikeFromlastYear      16
# CouponUsed                       17
# OrderCount                       16
# DaySinceLastOrder                22
# CashbackAmount                  220
# dtype: int64

# %% [markdown]
# #### One Hot Encoding for categorical feature

# %% [markdown]
# pd.get_dummies(df)

# %%
cls = df['PreferredLoginDevice']
df1 = pd.DataFrame(cls)

one_hot = pd.get_dummies(df['PreferredLoginDevice'], prefix='PreferredLoginDevice')
df1 = df1.join(one_hot)
df1
# Out:
#      PreferredLoginDevice  PreferredLoginDevice_Computer  \
# 0            Mobile Phone                              0
# 1                   Phone                              0
# 2                   Phone                              0
# 3                   Phone                              0
# 4                   Phone                              0
# ...                   ...                            ...
# 5625             Computer                              1
# 5626         Mobile Phone                              0
# 5627         Mobile Phone                              0
# 5628             Computer                              1
# 5629         Mobile Phone                              0
#
#       PreferredLoginDevice_Mobile Phone  PreferredLoginDevice_Phone
# 0                                     1                           0
# 1                                     0                           1
# 2                                     0                           1
# ...

# %%
cls = df['CityTier']
df1 = pd.DataFrame(cls)

one_hot = pd.get_dummies(df['CityTier'], prefix='CityTier')
df1 = df1.join(one_hot)
df1
# Out:
#       CityTier  CityTier_1  CityTier_2  CityTier_3
# 0            3           0           0           1
# 1            1           1           0           0
# 2            1           1           0           0
# 3            3           0           0           1
# 4            1           1           0           0
# ...        ...         ...         ...         ...
# 5625         1           1           0           0
# 5626         1           1           0           0
# 5627         1           1           0           0
# 5628         3           0           0           1
# 5629         1           1           0           0
#
# [5630 rows x 4 columns]

# %%
cls = df['PreferredPaymentMode']
df1 = pd.DataFrame(cls)

one_hot = pd.get_dummies(df['PreferredPaymentMode'], prefix='PreferredPaymentMode')
df1 = df1.join(one_hot)
df1
# Out:
#      PreferredPaymentMode  PreferredPaymentMode_CC  PreferredPaymentMode_COD  \
# 0              Debit Card                        0                         0
# 1                     UPI                        0                         0
# 2              Debit Card                        0                         0
# 3              Debit Card                        0                         0
# 4                      CC                        1                         0
# ...                   ...                      ...                       ...
# 5625          Credit Card                        0                         0
# 5626          Credit Card                        0                         0
# 5627           Debit Card                        0                         0
# 5628          Credit Card                        0                         0
# 5629          Credit Card                        0                         0
#
# ...

# %%
cls = df['Gender']
df1 = pd.DataFrame(cls)

one_hot = pd.get_dummies(df['Gender'], prefix='Gender')
df1 = df1.join(one_hot)
df1
# Out:
#       Gender  Gender_Female  Gender_Male
# 0     Female              1            0
# 1       Male              0            1
# 2       Male              0            1
# 3       Male              0            1
# 4       Male              0            1
# ...      ...            ...          ...
# 5625    Male              0            1
# 5626    Male              0            1
# 5627    Male              0            1
# 5628    Male              0            1
# 5629    Male              0            1
#
# [5630 rows x 3 columns]

# %%
cls = df['PreferedOrderCat']
df1 = pd.DataFrame(cls)

one_hot = pd.get_dummies(df['PreferedOrderCat'], prefix='PreferedOrderCat')
df1 = df1.join(one_hot)
df1
# Out:
#         PreferedOrderCat  PreferedOrderCat_Fashion  PreferedOrderCat_Grocery  \
# 0     Laptop & Accessory                         0                         0
# 1                 Mobile                         0                         0
# 2                 Mobile                         0                         0
# 3     Laptop & Accessory                         0                         0
# 4                 Mobile                         0                         0
# ...                  ...                       ...                       ...
# 5625  Laptop & Accessory                         0                         0
# 5626             Fashion                         1                         0
# 5627  Laptop & Accessory                         0                         0
# 5628  Laptop & Accessory                         0                         0
# 5629  Laptop & Accessory                         0                         0
#
# ...

# %%
cls = df['SatisfactionScore']
df1 = pd.DataFrame(cls)

one_hot = pd.get_dummies(df['SatisfactionScore'], prefix='SatisfactionScore')
df1 = df1.join(one_hot)
df1
# Out:
#       SatisfactionScore  SatisfactionScore_1  SatisfactionScore_2  \
# 0                     2                    0                    1
# 1                     3                    0                    0
# 2                     3                    0                    0
# 3                     5                    0                    0
# 4                     5                    0                    0
# ...                 ...                  ...                  ...
# 5625                  1                    1                    0
# 5626                  5                    0                    0
# 5627                  4                    0                    0
# 5628                  4                    0                    0
# 5629                  3                    0                    0
#
#       SatisfactionScore_3  SatisfactionScore_4  SatisfactionScore_5
# 0                       0                    0                    0
# ...

# %%
cls = df['MaritalStatus']
df1 = pd.DataFrame(cls)

one_hot = pd.get_dummies(df['MaritalStatus'], prefix='MaritalStatus')
df1 = df1.join(one_hot)
df1
# Out:
#      MaritalStatus  MaritalStatus_Divorced  MaritalStatus_Married  \
# 0           Single                       0                      0
# 1           Single                       0                      0
# 2           Single                       0                      0
# 3           Single                       0                      0
# 4           Single                       0                      0
# ...            ...                     ...                    ...
# 5625       Married                       0                      1
# 5626       Married                       0                      1
# 5627       Married                       0                      1
# 5628       Married                       0                      1
# 5629       Married                       0                      1
#
#       MaritalStatus_Single
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        1
# ...

# %%
cls = df['Complain']
df1 = pd.DataFrame(cls)

one_hot = pd.get_dummies(df['Complain'], prefix='Complain')
df1 = df1.join(one_hot)
df1
# Out:
#       Complain  Complain_0  Complain_1
# 0            1           0           1
# 1            1           0           1
# 2            1           0           1
# 3            0           1           0
# 4            0           1           0
# ...        ...         ...         ...
# 5625         0           1           0
# 5626         0           1           0
# 5627         1           0           1
# 5628         0           1           0
# 5629         0           1           0
#
# [5630 rows x 3 columns]

# %%
cls = df['Churn']
df1 = pd.DataFrame(cls)

one_hot = pd.get_dummies(df['Churn'], prefix='Churn')
df1 = df1.join(one_hot)
df1
# Out:
#       Churn  Churn_0  Churn_1
# 0         1        0        1
# 1         1        0        1
# 2         1        0        1
# 3         1        0        1
# 4         1        0        1
# ...     ...      ...      ...
# 5625      0        1        0
# 5626      0        1        0
# 5627      0        1        0
# 5628      0        1        0
# 5629      0        1        0
#
# [5630 rows x 3 columns]

# %% [markdown]
# ## Stratified sampling

# %%
df.columns
# Out:
# Index(['CustomerID', 'Churn', 'Tenure', 'PreferredLoginDevice', 'CityTier',
#        'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore',
#        'MaritalStatus', 'NumberOfAddress', 'Complain',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount'],
#       dtype='object')

# %%
df['Churn'].value_counts()
# Out:
# 0    4682
# 1     948
# Name: Churn, dtype: int64

# %%
(df['Churn'].value_counts()) / len(df)  * 100
# Out:
# 0    83.161634
# 1    16.838366
# Name: Churn, dtype: float64

# %%
df.groupby('Churn', group_keys=False).apply(lambda x: x.sample(4))
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 3872       53873      0    10.0             Computer         1
# 948        50949      0     1.0         Mobile Phone         1
# 3051       53052      0    14.0                Phone         1
# 58         50059      0    23.0                Phone         1
# 3711       53712      1     1.0         Mobile Phone         3
# 2978       52979      1     1.0                Phone         1
# 5220       55221      1     1.0             Computer         1
# 1641       51642      1     9.0         Mobile Phone         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 3872              7.0          Credit Card  Female             3.0
# 948              35.0           Debit Card    Male             3.0
# 3051             17.0           Debit Card  Female             3.0
# 58                6.0          Credit Card    Male             2.0
# ...

# %%
df.groupby('Churn', group_keys=False).apply(lambda x: x.sample(frac=1))
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 2726       52727      0     9.0             Computer         1
# 4238       54239      0    11.0         Mobile Phone         1
# 957        50958      0     9.0                Phone         1
# 4057       54058      0     1.0                Phone         1
# 214        50215      0     0.0         Mobile Phone         3
# ...          ...    ...     ...                  ...       ...
# 1146       51147      1     0.0                Phone         3
# 2457       52458      1     1.0                Phone         1
# 5499       55500      1     1.0         Mobile Phone         1
# 3452       53453      1     1.0             Computer         1
# 5193       55194      1     1.0             Computer         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 2726             22.0                   CC    Male             2.0
# 4238             14.0          Credit Card    Male             2.0
# ...

# %%
sns.histplot(df.Churn)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='Count'>

# %%
df['PreferredLoginDevice'].value_counts()
# Out:
# Mobile Phone    2765
# Computer        1634
# Phone           1231
# Name: PreferredLoginDevice, dtype: int64

# %%
(df['PreferredLoginDevice'].value_counts()) / len(df)  * 100
# Out:
# Mobile Phone    49.111901
# Computer        29.023091
# Phone           21.865009
# Name: PreferredLoginDevice, dtype: float64

# %%
df.groupby('PreferredLoginDevice', group_keys=False).apply(lambda x: x.sample(frac=1))
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 3155       53156      0    20.0             Computer         1
# 2161       52162      0    12.0             Computer         1
# 1658       51659      0     6.0             Computer         1
# 1582       51583      0    25.0             Computer         3
# 1073       51074      0     6.0             Computer         3
# ...          ...    ...     ...                  ...       ...
# 3352       53353      1     1.0                Phone         3
# 414        50415      0    23.0                Phone         3
# 3202       53203      0     1.0                Phone         1
# 373        50374      0     0.0                Phone         1
# 226        50227      0     5.0                Phone         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 3155             25.0          Credit Card  Female             3.0
# 2161             15.0           Debit Card    Male             3.0
# ...

# %%
sns.countplot(x='PreferredLoginDevice' ,data=df, palette= 'magma')
sns.histplot(df.PreferredLoginDevice)
# Out:
# <AxesSubplot:xlabel='PreferredLoginDevice', ylabel='count'>

# %%
df['PreferredPaymentMode'].value_counts()
# Out:
# Debit Card          2314
# Credit Card         1501
# E wallet             614
# UPI                  414
# COD                  365
# CC                   273
# Cash on Delivery     149
# Name: PreferredPaymentMode, dtype: int64

# %%
(df['PreferredPaymentMode'].value_counts()) / len(df)  * 100
# Out:
# Debit Card          41.101243
# Credit Card         26.660746
# E wallet            10.905861
# UPI                  7.353464
# COD                  6.483126
# CC                   4.849023
# Cash on Delivery     2.646536
# Name: PreferredPaymentMode, dtype: float64

# %%
df.groupby('PreferredPaymentMode', group_keys=False).apply(lambda x: x.sample(frac=1))
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 360        50361      0     9.0                Phone         1
# 495        50496      0     8.0                Phone         1
# 2727       52728      0     4.0             Computer         1
# 1099       51100      0     9.0                Phone         1
# 1617       51618      0     9.0                Phone         1
# ...          ...    ...     ...                  ...       ...
# 982        50983      0    11.0             Computer         2
# 615        50616      0     8.0                Phone         1
# 4237       54238      0    19.0         Mobile Phone         1
# 5472       55473      1     1.0         Mobile Phone         2
# 2625       52626      0    10.0                Phone         2
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 360              12.0                   CC  Female             3.0
# 495              14.0                   CC  Female             2.0
# ...

# %%
sns.countplot(x='PreferredPaymentMode' ,data=df, palette= 'Paired')
sns.histplot(df.PreferredPaymentMode)
# Out:
# <AxesSubplot:xlabel='PreferredPaymentMode', ylabel='count'>

# %%
df['Gender'].value_counts()
# Out:
# Male      3384
# Female    2246
# Name: Gender, dtype: int64

# %%
(df['Gender'].value_counts()) / len(df)  * 100
# Out:
# Male      60.106572
# Female    39.893428
# Name: Gender, dtype: float64

# %%
df.groupby('Gender', group_keys=False).apply(lambda x: x.sample(frac=1))
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 5299       55300      0     6.0         Mobile Phone         1
# 687        50688      0    16.0             Computer         1
# 2652       52653      0     1.0                Phone         1
# 4713       54714      0    14.0                Phone         1
# 5076       55077      0    20.0         Mobile Phone         3
# ...          ...    ...     ...                  ...       ...
# 3651       53652      0     9.0             Computer         1
# 2029       52030      0    13.0         Mobile Phone         3
# 3525       53526      0     9.0         Mobile Phone         2
# 1643       51644      0     9.0             Computer         1
# 3826       53827      1     1.0                Phone         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 5299             12.0                  UPI  Female             3.0
# 687              33.0           Debit Card  Female             2.0
# ...

# %%
sns.countplot(x='Gender' ,data=df, palette= 'Paired')
sns.histplot(df.Gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
df['PreferedOrderCat'].value_counts()
# Out:
# Laptop & Accessory    2050
# Mobile Phone          1271
# Fashion                826
# Mobile                 809
# Grocery                410
# Others                 264
# Name: PreferedOrderCat, dtype: int64

# %%
(df['PreferedOrderCat'].value_counts()) / len(df)  * 100
# Out:
# Laptop & Accessory    36.412078
# Mobile Phone          22.575488
# Fashion               14.671403
# Mobile                14.369449
# Grocery                7.282416
# Others                 4.689165
# Name: PreferedOrderCat, dtype: float64

# %%
df.groupby('PreferedOrderCat', group_keys=False).apply(lambda x: x.sample(frac=1))
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 5244       55245      0     8.0         Mobile Phone         3
# 3789       53790      0    19.0         Mobile Phone         1
# 399        50400      0     7.0         Mobile Phone         1
# 4865       54866      0    13.0         Mobile Phone         3
# 5517       55518      0    16.0         Mobile Phone         1
# ...          ...    ...     ...                  ...       ...
# 4347       54348      0    29.0         Mobile Phone         1
# 2258       52259      1     8.0         Mobile Phone         3
# 4404       54405      0    19.0         Mobile Phone         1
# 4266       54267      0    24.0             Computer         1
# 645        50646      0    19.0         Mobile Phone         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 5244              8.0     Cash on Delivery    Male             4.0
# 3789              7.0     Cash on Delivery    Male             4.0
# ...

# %%
sns.countplot(x='PreferedOrderCat' ,data=df, palette= 'Paired')
sns.histplot(df.PreferedOrderCat)
# Out:
# <AxesSubplot:xlabel='PreferedOrderCat', ylabel='count'>

# %%
df['SatisfactionScore'].value_counts()
# Out:
# 3    1698
# 1    1164
# 5    1108
# 4    1074
# 2     586
# Name: SatisfactionScore, dtype: int64

# %%
(df['SatisfactionScore'].value_counts()) / len(df)  * 100
# Out:
# 3    30.159858
# 1    20.674956
# 5    19.680284
# 4    19.076377
# 2    10.408526
# Name: SatisfactionScore, dtype: float64

# %%
df.groupby('SatisfactionScore', group_keys=False).apply(lambda x: x.sample(frac=1))
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 2139       52140      0     7.0             Computer         1
# 1375       51376      0     6.0                Phone         1
# 4497       54498      0     3.0         Mobile Phone         1
# 5469       55470      0     1.0         Mobile Phone         3
# 4288       54289      0     1.0         Mobile Phone         1
# ...          ...    ...     ...                  ...       ...
# 111        50112      1     0.0                Phone         1
# 3981       53982      1     1.0         Mobile Phone         1
# 1067       51068      0    22.0                Phone         1
# 2496       52497      0     1.0                Phone         1
# 2393       52394      0     7.0                Phone         3
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 2139              9.0           Debit Card    Male             2.0
# 1375             14.0                   CC    Male             3.0
# ...

# %%
df['MaritalStatus'].value_counts()
# Out:
# Married     2986
# Single      1796
# Divorced     848
# Name: MaritalStatus, dtype: int64

# %%
(df['MaritalStatus'].value_counts()) / len(df)  * 100
# Out:
# Married     53.037300
# Single      31.900533
# Divorced    15.062167
# Name: MaritalStatus, dtype: float64

# %%
df.groupby('MaritalStatus', group_keys=False).apply(lambda x: x.sample(frac=1))
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 720        50721      0    13.0             Computer         1
# 2893       52894      0    14.0         Mobile Phone         1
# 2835       52836      1     1.0         Mobile Phone         3
# 513        50514      0     0.0                Phone         3
# 288        50289      0    15.0             Computer         1
# ...          ...    ...     ...                  ...       ...
# 387        50388      0     9.0                Phone         1
# 2237       52238      1     9.0             Computer         1
# 4208       54209      0    20.0             Computer         3
# 669        50670      0     7.0             Computer         1
# 325        50326      0     4.0         Mobile Phone         3
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 720              32.0          Credit Card  Female             3.0
# 2893             26.0          Credit Card    Male             3.0
# ...

# %%
sns.countplot(x='MaritalStatus' ,data=df, palette= 'Paired')
sns.histplot(df.MaritalStatus)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
(df['Complain'].value_counts()) / len(df)  * 100
# Out:
# 0    71.509769
# 1    28.490231
# Name: Complain, dtype: float64

# %%
df.groupby('Complain', group_keys=False).apply(lambda x: x.sample(frac=1))
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 37         50038      0     1.0                Phone         1
# 207        50208      0    27.0             Computer         1
# 1458       51459      0     0.0                Phone         1
# 413        50414      0    14.0         Mobile Phone         2
# 5445       55446      0    20.0             Computer         3
# ...          ...    ...     ...                  ...       ...
# 1922       51923      0    10.0                Phone         1
# 5455       55456      0    15.0         Mobile Phone         3
# 4446       54447      1     8.0             Computer         1
# 3002       53003      0     5.0         Mobile Phone         1
# 5492       55493      1     1.0             Computer         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 37               27.0                   CC    Male             3.0
# 207              26.0           Debit Card  Female             2.0
# ...

# %% [markdown]
# ### Correlation Matrix

# %%
df.corr()
# Out:
#                              CustomerID     Churn    Tenure  CityTier  \
# CustomerID                     1.000000 -0.019083  0.035096  0.003239
# Churn                         -0.019083  1.000000 -0.337831  0.084703
# Tenure                         0.035096 -0.337831  1.000000 -0.057895
# CityTier                       0.003239  0.084703 -0.057895  1.000000
# WarehouseToHome                0.065120  0.069544 -0.012191  0.013576
# HourSpendOnApp                 0.580301  0.018816 -0.017282 -0.009921
# NumberOfDeviceRegistered       0.411098  0.107939 -0.020657  0.027934
# SatisfactionScore             -0.033146  0.105481 -0.014452 -0.011554
# NumberOfAddress                0.160814  0.043931  0.235076 -0.029440
# Complain                      -0.009944  0.250188 -0.020535  0.003375
# OrderAmountHikeFromlastYear    0.110825 -0.007075 -0.005542 -0.028890
# CouponUsed                     0.232656 -0.001430  0.101535  0.022629
# ...

# %%
#Correlation plot
sns.set(rc = {'figure.figsize':(20, 18)})
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Feature scaling

# %%
#Normalization for Numerical features
from sklearn.preprocessing import MinMaxScaler

# %%
scaler= MinMaxScaler()

# %%
scaler.fit_transform(df[['CustomerID','Tenure', 'WarehouseToHome','HourSpendOnApp','NumberOfDeviceRegistered','NumberOfAddress','OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
       'DaySinceLastOrder', 'CashbackAmount' ]])
# Out:
# array([[0.00000000e+00, 6.55737705e-02, 8.19672131e-03, ...,
#         0.00000000e+00, 1.08695652e-01, 4.92307692e-01],
#        [1.77651448e-04, 1.47540984e-01, 2.45901639e-02, ...,
#         0.00000000e+00, 0.00000000e+00, 3.72307692e-01],
#        [3.55302896e-04, 1.47540984e-01, 2.04918033e-01, ...,
#         0.00000000e+00, 6.52173913e-02, 3.69230769e-01],
#        ...,
#        [9.99644697e-01, 1.63934426e-02, 4.91803279e-02, ...,
#         6.66666667e-02, 8.69565217e-02, 5.72307692e-01],
#        [9.99822349e-01, 3.77049180e-01, 3.27868852e-02, ...,
#         6.66666667e-02, 1.95652174e-01, 5.50769231e-01],
#        [1.00000000e+00, 1.31147541e-01, 8.19672131e-02, ...,
#         6.66666667e-02, 6.52173913e-02, 5.20000000e-01]])

# %%
#Standardisation for Numerical features
from sklearn.preprocessing import StandardScaler

# %%
Standardisation= StandardScaler()  #object create

# %%
Standardisation.fit_transform(df[['CustomerID','Tenure', 'WarehouseToHome','HourSpendOnApp','NumberOfDeviceRegistered','NumberOfAddress','OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
       'DaySinceLastOrder', 'CashbackAmount' ]])
# Out:
# array([[-1.73174319, -0.73398944, -1.14637901, ..., -0.68142312,
#          0.15143648, -0.35010504],
#        [-1.73112789, -0.13570356, -0.90672086, ..., -0.68142312,
#         -1.24900275, -1.14295718],
#        [-1.7305126 , -0.13570356,  1.72951879, ..., -0.68142312,
#         -0.40873921, -1.16328672],
#        ...,
#        [ 1.7305126 , -1.09296096, -0.54723363, ..., -0.33407933,
#         -0.12865136,  0.17846305],
#        [ 1.73112789,  1.53949688, -0.78689178, ..., -0.33407933,
#          1.27178787,  0.03615625],
#        [ 1.73174319, -0.25536074, -0.06791733, ..., -0.33407933,
#         -0.40873921, -0.16713917]])

# %%
df.to_csv('cleaned.csv')
